# %% [markdown]
# <h1 style='text-align: center'>Color extraction from images</h1>

# %%
# %config IPCompleter.greedy=True
# %matplotlib inline

# %%
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import cv2

# %%
image = plt.imread('city.jpg')
type(image)
# Out:
# numpy.ndarray

# %%
plt.imshow(image)

# %%
#list of pixels to dataframe
import pandas as pd
lst_pixels = image.reshape((image.shape[0] * image.shape[1], 3))
X = pd.DataFrame(lst_pixels, columns=['R','G','B'])
X[:5]
# Out:
#      R    G    B
# 0  137  207  243
# 1  131  201  237
# 2  128  198  234
# 3  130  200  236
# 4  131  201  237

# %%
#our img size
image.shape
# Out:
# (473, 840, 3)

# %%
#numpy reshape
lst_pixels = image.reshape((image.shape[0] * image.shape[1], 3))

# %%
#train our classifier
from sklearn.cluster import k_means
model = KMeans(n_clusters=3, random_state=0) 
clf = model.fit(X)

# %%
#Top k colors
clf.cluster_centers_
# Out:
# array([[ 121.20165396,  198.87320117,  227.6029979 ],
#        [ 194.14149529,   83.75737145,   89.97822146],
#        [ 239.35613114,  231.30216896,  223.99153367]])

# %%
clf.cluster_centers_.flatten().reshape(3,3)
# Out:
# array([[ 121.20165396,  198.87320117,  227.6029979 ],
#        [ 194.14149529,   83.75737145,   89.97822146],
#        [ 239.35613114,  231.30216896,  223.99153367]])

# %%
colors_predicted = clf.cluster_centers_[predictions]
colors_predicted
# Out:
# array([[ 121.20165396,  198.87320117,  227.6029979 ],
#        [ 121.20165396,  198.87320117,  227.6029979 ],
#        [ 121.20165396,  198.87320117,  227.6029979 ],
#        ...,
#        [ 239.35613114,  231.30216896,  223.99153367],
#        [ 121.20165396,  198.87320117,  227.6029979 ],
#        [ 121.20165396,  198.87320117,  227.6029979 ]])

# %%
colors_predicted == clf.cluster_centers_[0]
# Out:
# array([[ True,  True,  True],
#        [ True,  True,  True],
#        [ True,  True,  True],
#        ...,
#        [False, False, False],
#        [ True,  True,  True],
#        [ True,  True,  True]], dtype=bool)

# %%
colors_predicted[colors_predicted == clf.cluster_centers_[0]]
# Out:
# array([ 121.20165396,  198.87320117,  227.6029979 , ...,  121.20165396,
#         198.87320117,  227.6029979 ])

# %%
wanted = clf.cluster_centers_[0]
wanted
result = colors_predicted[np.logical_or.reduce([colors_predicted[:,1] == x for x in wanted])]
len(result)/colors_predicted.shape[0]
# Out:
# 0.5715644820295983

# %%
wanted = clf.cluster_centers_[1]
wanted
result = colors_predicted[np.logical_or.reduce([colors_predicted[:,1] == x for x in wanted])]
len(result), colors_predicted.shape
# Out:
# (76651, (397320, 3))

# %%
wanted = clf.cluster_centers_[2]
wanted
result = colors_predicted[np.logical_or.reduce([colors_predicted[:,1] == x for x in wanted])]
len(result), colors_predicted.shape
# Out:
# (93575, (397320, 3))

# %%
from bokeh.layouts import gridplot
from bokeh.plotting import figure, show, output_notebook
import numpy as np
import scipy

output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="4a97b4b7-a276-4aac-8a4c-45365470aa46">Loading BokehJS ...</span>
#     </div>
